# %% [markdown]
# # Aclaraciones porfavor leer
#
# - Si alguna libreria no aparece porfavor instalar, en este caso installar prettytable y  ipympl con pip install prettytable y pip install ipympl. Si esto aún no funciona puede correr en mi binder https://mybinder.org/v2/gh/Ratabart666/Ratabart666/HEAD

# %% [markdown]
# # Datos y librerias

# %%
import pandas as pd
import numpy as np
from prettytable import MSWORD_FRIENDLY
from prettytable.colortable import ColorTable, Themes
from prettytable import PrettyTable
import matplotlib.pyplot as plt
datos = pd.read_csv('trabajo.txt', delimiter='\t')
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Visualizando datos, obteniendo muestras y aclarando información cada columna

# %% [markdown]
# **inlf**: 1 si participa la esposa en el mercado laboral, 0 de lo contrario
#
# **horas_esposa**:horas laboradas esposa
#
# **hijos** :número hijos menores a 6 años
#
# **edad_esposa**:edad en años esposa
#
# **educ_esposa**:años educación esposa
#
# **horas_esposo**:horas laboradas por el esposo
#
# **edad_esposo**:años de edad del esposo
#
# **educ_esposo**:años educación esposo
#
# **ingreso**:ingreso del hogar mensual
#
# **exper_esposa**:experiencia laboral en años
#
# **d_hijo6**:1 si tiene al menos un hijo menor de 6 años, 0 de lo contrario
#
# **salario_esposa**:salario laboral por hora esposa
#
# **salario_esposo**:salario laboral por hora esposa
#
# **Tipo_empleo**
#
# **Dpto_residencia**

# %%
datos
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 0       1          1610      1           32           12          2708
# 1       1          1656      0           30           12          2310
# 2       1          1980      1           35           12          3072
# 3       1           456      0           34           12          1920
# 4       1          1568      1           31           14          2000
# ..    ...           ...    ...          ...          ...           ...
# 748     0             0      0           40           13          3020
# 749     0             0      2           31           12          2056
# 750     0             0      0           43           12          2383
# 751     0             0      0           60           12          1705
# 752     0             0      0           39            9          3120
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 0             34           12   815500            14        1      12745.2000
# 1             30            9  1090000             5        0       5277.8203
# 2             40           12  1052000            15        1      17272.8980
# 3             53           10   365000             6        0       4166.7002
# 4             32           12  1365000             7        1      17448.8400
# ..           ...          ...      ...           ...      ...             ...
# 748           43           16  1410000             5        0          0.0000
# 749           33           12   500000            14        1          0.0000
# 750           43           12   497600             4        0          0.0000
# 751           55            8  1249200            15        0          0.0000
# 752           48           12  1418150            12        0          0.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 0        15309.4400          1.0                3
# 1        32078.0800          1.0                1
# 2        13606.6600          1.0                2
# 3        13458.4600          1.0                2
# 4        38000.0000          1.0                2
# ..              ...          ...              ...
# 748      35231.6990          1.0                1
# 749      18482.4390          1.0                3
# 750       4141.2402          1.0                2
# 751      47272.0000          1.0                2
# 752      23140.8610          2.0                1
#
# [753 rows x 15 columns]

# %%
muestra=datos.sample(50)

# %%
muestra
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 569     0             0      0           32           12          1960
# 629     0             0      1           41           12          3080
# 739     0             0      0           48           11          2185
# 249     1          1260      1           30           16          2450
# 358     1           651      0           54            9          2400
# 459     0             0      0           54           12          2610
# 232     1          1410      1           30           12          2106
# 110     1           215      2           31           17          1920
# 712     0             0      0           47           12          2700
# 698     0             0      1           47           17          1930
# 699     0             0      0           54           12          1350
# 432     0             0      0           45           12          2250
# 52      1           340      0           37           12          2152
# 147     1          1904      0           36           12          2860
# 659     0             0      1           45            9          1920
# 380     1          1253      0           35           16          2504
# 641     0             0      1           36           12          2450
# 234     1          1640      0           38           12          2040
# 14      1          1848      0           43           10          2024
# 370     1           300      0           37           14          2895
# 235     1          1202      0           43           12          2856
# 386     1          1225      0           35           10          1560
# 238     1           526      0           38           17          1896
# 274     1          3120      0           41           12          2632
# 190     1          1670      0           54           12          2600
# 474     0             0      0           38           12          2196
# 260     1           200      0           54           12          2040
# 287     1          2012      0           34           12          2666
# 478     0             0      1           33           12          2750
# 285     1           450      0           51           13          2600
# 143     1          1840      0           51           12          2832
# 462     0             0      2           34           12          3160
# 422     1           460      2           32           17          1850
# 609     0             0      0           47           13          1360
# 669     0             0      0           50           12          1700
# 748     0             0      0           40           13          3020
# 174     1           800      0           32           12          2070
# 733     0             0      0           31           12          2250
# 197     1          1500      0           51           12          3000
# 268     1          1960      0           47           14          2500
# 142     1           910      0           41           14          1820
# 247     1          1520      0           43           10          3000
# 614     0             0      0           44           12          1800
# 223     1           675      0           37           12          2651
# 443     0             0      0           44           12          4640
# 150     1           740      0           42           17          2880
# 369     1          1621      0           50           17          2364
# 269     1            44      1           36           16          1840
# 388     1           480      0           30           14          2080
# 355     1            63      1           35           16          2385
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 569           35           12   550000             4        0          0.0000
# 629           43           12  1531150             5        1          0.0000
# 739           48           12  1555300             6        0          0.0000
# 249           34           17  1727500             9        1      31063.4790
# 358           57           10  1082500             9        0       8171.9004
# 459           53           12  1047500            10        0          0.0000
# 232           30           14  1304000            11        1      18865.1000
# 110           32           16   812250             7        1      35348.7420
# 712           48           12  1410000             3        0          0.0000
# 698           57           16   986500            15        1          0.0000
# 699           60           12  1750000            10        0          0.0000
# 432           46           16  1085000            12        0          0.0000
# 52            40           10   832900            15        0       4470.6997
# 147           37           12  1843600            14        0      17962.2210
# 659           35            9   504500            10        1          0.0000
# 380           33           10   388700             7        0      23664.5000
# 641           40           16  1345000             0        1          0.0000
# 234           46           12   625000            19        0      13902.3000
# 14            45           17  1571550             6        0      13982.8590
# 370           38           14  1862500            13        0      31666.5390
# 235           48           16  1780000             7        0      20495.2990
# 386           43            9   538800             4        0      11167.4400
# 238           42           17  1826250            10        0      32509.3810
# 274           44           13  1630000             7        0       6771.9800
# 190           56            8   855000            19        0       8646.5195
# 474           42           11   834100            19        0          0.0000
# 260           54           16  1760350             3        0       6650.0000
# 287           34           10   465000            14        0      10198.8200
# 478           34           12   911000             5        1          0.0000
# 285           57           14  2045000            19        0      21111.2810
# 143           53            8   911600            27        0       9293.6602
# 462           30           12   250000            10        1          0.0000
# 422           31           17   865000            14        1      18173.8790
# 609           49           16  2805000            11        0          0.0000
# 669           53           17  1515000             6        0          0.0000
# 748           43           16  1410000             5        0          0.0000
# 174           31           16  1370000            12        0       8550.0000
# 733           37           14   900000            12        0          0.0000
# 197           51           12  1229000            14        0       9880.0000
# 268           50           12  2260250             7        0      38775.2030
# 142           40           17   800000            23        0      16703.2790
# 247           50           12  1850000            13        0      29999.8590
# 614           45           12   669500             3        0          0.0000
# 223           48           17  1048000            11        0      10133.4600
# 443           50           12   656300             3        0          0.0000
# 150           45           16  1540000            14        0      16946.1000
# 369           52           17  2177500            12        0      24614.5000
# 269           37           17   725000             3        1      25909.1600
# 388           34           14  1195000            12        0      26125.0000
# 355           37           16  1187500             7        1      15079.5400
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 569      21326.3590          1.0                1
# 629      32549.2810          1.0                1
# 739      30434.9610          1.0                2
# 249      31020.5390          1.0                1
# 358      31350.0000          1.0                2
# 459      24022.8420          1.0                1
# 232      32478.6000          1.0                3
# 110      27708.4590          2.0                3
# 712      13159.4000          1.0                1
# 698      30911.8590          2.0                1
# 699      45527.8010          1.0                3
# 432      35466.5390          2.0                1
# 52       23838.1600          2.0                2
# 147      19172.8980          1.0                2
# 659      19573.8010          1.0                1
# 380       2220.3398          1.0                2
# 641      34122.4800          1.0                3
# 234      12107.9400          1.0                2
# 14       41306.0000          2.0                3
# 370      49878.8010          1.0                2
# 235      17277.0800          1.0                1
# 386      14615.5600          1.0                2
# 238      62331.3980          1.0                3
# 274      32138.1210          2.0                3
# 190      17392.2210          1.0                3
# 474      21630.3610          1.0                3
# 260      59606.8010          1.0                3
# 287       5188.1401          2.0                3
# 478      25149.1600          1.0                2
# 285      43844.4020          2.0                3
# 143      16513.6600          2.0                2
# 462       2886.1001          1.0                1
# 422      30810.7790          2.0                2
# 609     153675.8100          2.0                1
# 669      35429.2970          1.0                3
# 748      35231.6990          1.0                1
# 174      44057.1990          1.0                3
# 733      30400.0000          1.0                1
# 197      22800.0000          2.0                3
# 268      24852.0000          1.0                2
# 142      25054.9200          2.0                3
# 247      30400.0000          1.0                1
# 614      19316.5410          2.0                2
# 223      27234.9800          1.0                1
# 443       7026.5801          2.0                1
# 150      35625.0000          2.0                2
# 369      53044.1990          1.0                1
# 269      22717.5410          1.0                2
# 388      33469.2620          1.0                3
# 355      36645.6840          2.0                3

# %% [markdown]
# # Tabla de frecuencias variables

# %%
def tabla_serie(serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    x = PrettyTable()
    x = ColorTable(theme=Themes.OCEAN)
    x.field_names = ['Intervalo '+serie.name,
                     'Frecuencia absoluta', 'Frecuencia porcentual(%)']
    Intervalo = ''
    Frecuencia = ''
    Frecuencia_por = ''
    for i in np.arange(minimo, maximo-amplitud, amplitud):
        Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+')'
        Frecuencia = serie[(serie >= i) & (serie < i+amplitud)].count()
        Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
        x.add_row([Intervalo, Frecuencia, Frecuencia_por])
    i = maximo-amplitud
    Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+']'
    Frecuencia = serie[(serie >= i) & (serie <= i+amplitud)].count()
    Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
    x.add_row([Intervalo, Frecuencia, Frecuencia_por])

    return x


def tabla_datos_agrupados_1(datos):
    'Dada algunos datos devuelve su información tabulada, cada columna corresponde a una variable'
    print('Tablas de frecuencia datos agrupados')
    print(' ')
    print('Nota: El número de datos por columna es:', len(datos))
    for i in datos:
        print(' ')
        print(100*'-')
        print(' ')
        print(tabla_serie(datos[i]))
    return ''


print(tabla_datos_agrupados_1(muestra.drop(
    ['Dpto_residencia', 'Tipo_empleo', 'd_hijo6', 'hijos', 'inlf'], axis=1)))
# Out:
# Tablas de frecuencia datos agrupados
#
# Nota: El número de datos por columna es: 50
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |      [0.0,445.71)      |          25         |           50.0           |
# |    [445.71,891.43)     |          8          |           16.0           |
# |    [891.43,1337.14)    |          5          |           10.0           |
# |   [1337.14,1782.86)    |          6          |           12.0           |
# |   [1782.86,2228.57)    |          5          |           10.0           |
# |   [2228.57,2674.29)    |          0          |           0.0            |
# |    [2674.29,3120.0]    |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [30.0,33.43)     |          9          |           18.0           |
# |     [33.43,36.86)     |          8          |           16.0           |
# |     [36.86,40.29)     |          7          |           14.0           |
# |     [40.29,43.71)     |          7          |           14.0           |
# |     [43.71,47.14)     |          8          |           16.0           |
# |     [47.14,50.57)     |          3          |           6.0            |
# |      [50.57,54.0]     |          8          |           16.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [9.0,10.14)      |          5          |           10.0           |
# |     [10.14,11.29)     |          1          |           2.0            |
# |     [11.29,12.43)     |          27         |           54.0           |
# |     [12.43,13.57)     |          3          |           6.0            |
# |     [13.57,14.71)     |          4          |           8.0            |
# |     [14.71,15.86)     |          0          |           0.0            |
# |      [15.86,17.0)     |          4          |           8.0            |
# |      [15.86,17.0]     |          10         |           20.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |    [1350.0,1820.0)     |          5          |           10.0           |
# |    [1820.0,2290.0)     |          19         |           38.0           |
# |    [2290.0,2760.0)     |          15         |           30.0           |
# |    [2760.0,3230.0)     |          10         |           20.0           |
# |    [3230.0,3700.0)     |          0          |           0.0            |
# |    [3700.0,4170.0)     |          0          |           0.0            |
# |    [4170.0,4640.0]     |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [30.0,34.29)     |          10         |           20.0           |
# |     [34.29,38.57)     |          7          |           14.0           |
# |     [38.57,42.86)     |          5          |           10.0           |
# |     [42.86,47.14)     |          9          |           18.0           |
# |     [47.14,51.43)     |          9          |           18.0           |
# |     [51.43,55.71)     |          5          |           10.0           |
# |      [55.71,60.0]     |          5          |           10.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [8.0,9.29)      |          4          |           8.0            |
# |      [9.29,10.57)     |          4          |           8.0            |
# |     [10.57,11.86)     |          1          |           2.0            |
# |     [11.86,13.14)     |          16         |           32.0           |
# |     [13.14,14.43)     |          5          |           10.0           |
# |     [14.43,15.71)     |          0          |           0.0            |
# |      [15.71,17.0]     |          20         |           40.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# |   Intervalo ingreso   | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |  [250000.0,615000.0)  |          6          |           12.0           |
# |  [615000.0,980000.0)  |          13         |           26.0           |
# |  [980000.0,1345000.0) |          9          |           18.0           |
# | [1345000.0,1710000.0) |          10         |           20.0           |
# | [1710000.0,2075000.0) |          9          |           18.0           |
# | [2075000.0,2440000.0) |          2          |           4.0            |
# | [2440000.0,2805000.0] |          1          |           2.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo exper_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |       [0.0,3.86)       |          6          |           12.0           |
# |      [3.86,7.71)       |          14         |           28.0           |
# |      [7.71,11.57)      |          10         |           20.0           |
# |     [11.57,15.43)      |          14         |           28.0           |
# |     [15.43,19.29)      |          4          |           8.0            |
# |     [19.29,23.14)      |          1          |           2.0            |
# |      [23.14,27.0]      |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |      [0.0,5539.31)       |          20         |           40.0           |
# |    [5539.31,11078.63)    |          9          |           18.0           |
# |   [11078.63,16617.94)    |          4          |           8.0            |
# |   [16617.94,22157.26)    |          7          |           14.0           |
# |   [22157.26,27696.57)    |          4          |           8.0            |
# |   [27696.57,33235.89)    |          4          |           8.0            |
# |    [33235.89,38775.2)    |          1          |           2.0            |
# |    [33235.89,38775.2]    |          2          |           4.0            |
# +--------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |    [2220.34,23856.84)    |          18         |           36.0           |
# |   [23856.84,45493.33)    |          26         |           52.0           |
# |   [45493.33,67129.83)    |          5          |           10.0           |
# |   [67129.83,88766.32)    |          0          |           0.0            |
# |   [88766.32,110402.82)   |          0          |           0.0            |
# |  [110402.82,132039.31)   |          0          |           0.0            |
# |  [132039.31,153675.81]   |          1          |           2.0            |
# +--------------------------+---------------------+--------------------------+

# %% [markdown]
# # Salario promedio

# %%
mujeres = round(muestra['salario_esposa'].mean())
hombres = round(muestra['salario_esposo'].mean())
print('El salario promedio para los esposos es:', hombres)
print('El salario promedio para las esposas es:', mujeres)
# Out:
# El salario promedio para los esposos es: 30891
# El salario promedio para las esposas es: 11337

# %% [markdown]
# # Histograma edad esposo

# %%
fig, ax = plt.subplots()
ax.hist(muestra['edad_esposo'])
ax.set_xlabel('Edad esposo')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma edad esposo')
# Out:
# Text(0.5, 1.0, 'Histograma edad esposo')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %%
edad_promedio = round(muestra['edad_esposa'].mean())
print('La edad promedio de la esposa es: '+str(edad_promedio)+' años')
# Out:
# La edad promedio de la esposa es: 41 años

# %% [markdown]
# La probabilidad de A bajo la condición que ya ocurrió B es:
#
# $$P(A|B)= \frac{P(A \cap B)}{P(B)}$$
#
# Por lo tanto tenemos que la probabilidad de que este en el mercado laboral, dado que tiene una edad promedio es:
# $$P=\frac{tenga \ edad \ promedio \ y \ este \ en \ el \ mercado  \ laboral}{probabilidad \ de \ que \ tenga \ edad \ promedio}$$

# %%
def buscar_intervalo(edad, serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    for i in np.arange(minimo, maximo, amplitud):
        if edad in range(round(i), round(i+amplitud)):
            return [i, i+amplitud]

# %%
rango = buscar_intervalo(edad_promedio, muestra['edad_esposa'])
print('El intervalo considerado para la edad promedio de',
      edad_promedio, ' años es: ', rango)
print(100*'-')
P1 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1])])/len(muestra)*100
P2 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1]) & muestra['inlf'] == 1])/len(muestra)*100
P = round(P2/P1, 2)
print('La probabilidad de que la esposa de edad promedio participe en el mercado laboral es ', P, '%')
# Out:
# El intervalo considerado para la edad promedio de 41  años es:  [40.28571428571429, 43.71428571428572]
# ----------------------------------------------------------------------------------------------------
# La probabilidad de que la esposa de edad promedio participe en el mercado laboral es  0.86 %

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %% [markdown]
# **Como este evento es el evento complemento del anterior**, entonces la probabilidad es igual a $100\%-probabilidad \ evento \ anterior$

# %%
print('La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es ', 100-P, '%')
# Out:
# La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es  99.14 %
