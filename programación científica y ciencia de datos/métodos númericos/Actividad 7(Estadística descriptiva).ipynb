# %% [markdown]
# # Aclaraciones porfavor leer
#
# - Si alguna libreria no aparece porfavor instalar, en este caso installar prettytable y  ipympl con pip install prettytable y pip install ipympl. Si esto aún no funciona puede correr en mi binder https://mybinder.org/v2/gh/Ratabart666/Ratabart666/HEAD

# %% [markdown]
# # Datos y librerias

# %%
import pandas as pd
import numpy as np
from prettytable import MSWORD_FRIENDLY
from prettytable.colortable import ColorTable, Themes
from prettytable import PrettyTable
import matplotlib.pyplot as plt
datos = pd.read_csv('trabajo.txt', delimiter='\t')
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Visualizando datos, obteniendo muestras y aclarando información cada columna

# %% [markdown]
# **inlf**: 1 si participa la esposa en el mercado laboral, 0 de lo contrario
#
# **horas_esposa**:horas laboradas esposa
#
# **hijos** :número hijos menores a 6 años
#
# **edad_esposa**:edad en años esposa
#
# **educ_esposa**:años educación esposa
#
# **horas_esposo**:horas laboradas por el esposo
#
# **edad_esposo**:años de edad del esposo
#
# **educ_esposo**:años educación esposo
#
# **ingreso**:ingreso del hogar mensual
#
# **exper_esposa**:experiencia laboral en años
#
# **d_hijo6**:1 si tiene al menos un hijo menor de 6 años, 0 de lo contrario
#
# **salario_esposa**:salario laboral por hora esposa
#
# **salario_esposo**:salario laboral por hora esposa
#
# **Tipo_empleo**
#
# **Dpto_residencia**

# %%
datos
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 0       1          1610      1           32           12          2708
# 1       1          1656      0           30           12          2310
# 2       1          1980      1           35           12          3072
# 3       1           456      0           34           12          1920
# 4       1          1568      1           31           14          2000
# ..    ...           ...    ...          ...          ...           ...
# 748     0             0      0           40           13          3020
# 749     0             0      2           31           12          2056
# 750     0             0      0           43           12          2383
# 751     0             0      0           60           12          1705
# 752     0             0      0           39            9          3120
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 0             34           12   815500            14        1      12745.2000
# 1             30            9  1090000             5        0       5277.8203
# 2             40           12  1052000            15        1      17272.8980
# 3             53           10   365000             6        0       4166.7002
# 4             32           12  1365000             7        1      17448.8400
# ..           ...          ...      ...           ...      ...             ...
# 748           43           16  1410000             5        0          0.0000
# 749           33           12   500000            14        1          0.0000
# 750           43           12   497600             4        0          0.0000
# 751           55            8  1249200            15        0          0.0000
# 752           48           12  1418150            12        0          0.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 0        15309.4400          1.0                3
# 1        32078.0800          1.0                1
# 2        13606.6600          1.0                2
# 3        13458.4600          1.0                2
# 4        38000.0000          1.0                2
# ..              ...          ...              ...
# 748      35231.6990          1.0                1
# 749      18482.4390          1.0                3
# 750       4141.2402          1.0                2
# 751      47272.0000          1.0                2
# 752      23140.8610          2.0                1
#
# [753 rows x 15 columns]

# %%
muestra=datos.sample(50)

# %%
muestra
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 557     0             0      0           44           12          2553
# 466     0             0      0           38           12          1980
# 291     1          3686      0           32           14          1647
# 528     0             0      0           59           12          1920
# 337     1           160      0           40           12          2450
# 215     1           210      0           46           16          2210
# 177     1          2272      0           37           11          3000
# 643     0             0      0           54           16          2701
# 445     0             0      1           35           14          1988
# 386     1          1225      0           35           10          1560
# 540     0             0      0           54            8          2860
# 686     0             0      0           54           15          1920
# 336     1          1877      0           45           12          1820
# 619     0             0      0           49           12          2115
# 453     0             0      0           53           12          1950
# 419     1          1984      1           36           11          1656
# 213     1           900      0           59           10          1820
# 354     1           608      0           45           17          2182
# 378     1           200      1           33           12          3680
# 149     1          1486      0           40           16          1800
# 681     0             0      1           37            9          2033
# 653     0             0      0           36           12          1634
# 500     0             0      0           50           12          1848
# 49      1           240      0           30           12          1864
# 263     1          2318      0           47           16          1911
# 34      1          2081      0           45           16          2140
# 369     1          1621      0           50           17          2364
# 575     0             0      0           52           12          2115
# 332     1          2000      0           56           12          2032
# 152     1          1275      0           43           12          2250
# 482     0             0      2           33           13          2677
# 216     1           239      1           41           12          2874
# 271     1          2540      0           41            8          3536
# 550     0             0      0           50           12          1920
# 60      1          2500      0           40           14          5010
# 125     1          4950      0           35           12          2504
# 138     1           120      1           33           12          2263
# 471     0             0      0           44           12          1680
# 556     0             0      0           49           12          2064
# 35      1           690      0           42           11          1896
# 77      1           337      0           49           17          1430
# 195     1          1984      0           40           12          1960
# 16      1          1400      0           43           12          2156
# 541     0             0      0           48           11          1765
# 474     0             0      0           38           12          2196
# 299     1          1688      0           32           17          1863
# 411     1           225      1           40           17          1278
# 240     1          1327      0           48           12           288
# 344     1           160      0           36           16          3120
# 675     0             0      0           50           12          2750
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 557           31           16   942500            15        0         0.00000
# 466           42           16  1655000             2        0         0.00000
# 291           39           14   650000            11        0      2061.87990
# 528           56           10   823800             7        0         0.00000
# 337           44           12   930000             6        0     16625.00000
# 215           49           12   411700             7        0      8034.33980
# 177           47            8   640000            18        0      6021.09960
# 643           54           17  1751000             1        0         0.00000
# 445           34           17   900500             3        1         0.00000
# 386           43            9   538800             4        0     11167.44000
# 540           49            8   650000            20        0         0.00000
# 686           52           15  1000000             6        0         0.00000
# 336           50            8  1199000            13        0     14171.72000
# 619           53           10   836800             2        0         0.00000
# 453           54           16  1388000            10        0         0.00000
# 419           38            8   980000            10        1     17046.42000
# 213           59            7   269000            14        0      8782.17970
# 354           47           16  2000250            10        0     26562.37900
# 378           33           16  2175000             4        1      9500.00000
# 149           54           16  1345000            17        0     28129.11900
# 681           37           17   870500            10        1         0.00000
# 653           45           17  1220000             5        0         0.00000
# 500           56           12  1080000             3        0         0.00000
# 49            37           12   349250             6        0     10022.50000
# 263           46           16  2545000             9        0     15573.92100
# 34            47           17  1232800            27        0     14465.84000
# 369           52           17  2177500            12        0     24614.50000
# 575           55           12   961850            23        0         0.00000
# 332           60           10   552500            26        0      9025.00000
# 152           47           14  1239750             7        0      7153.12010
# 482           37           17  2012500             4        1         0.00000
# 216           48           16  1032300             4        1     37745.77700
# 271           43           11  1760000            16        0      9303.91990
# 550           50           12  1470000             3        0         0.00000
# 60            42           13  1975000            19        0     16720.00000
# 125           37           12   935000            17        0       614.07996
# 138           32           14  1056000             3        1     12666.54000
# 471           46           12  1015000             5        0         0.00000
# 556           53           12   800000            15        0         0.00000
# 35            44            8   794850             0        0      9362.43950
# 77            47           17   480000            24        0     11276.12000
# 195           39           14  1401500             7        0     13943.72000
# 16            45           12   930000            20        0     12214.34000
# 541           49           12   898500            10        0         0.00000
# 474           42           11   834100            19        0         0.00000
# 299           33           17  1755000            15        0     38946.19900
# 411           38           17  1274500             8        1      6755.63960
# 240           51           11   415550            17        0     10022.50000
# 344           42           16   822500            14        0     15437.50000
# 675           52           10   561250             0        0         0.00000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 557      20540.5200          1.0                1
# 466      57577.6020          1.0                3
# 291      25379.4390          2.0                1
# 528      31619.0390          1.0                1
# 337      27763.1800          2.0                3
# 215      12706.8200          1.0                3
# 177      11400.0000          1.0                3
# 643      42206.6020          1.0                2
# 445      34406.3400          2.0                1
# 386      14615.5600          1.0                2
# 540      17006.9000          2.0                3
# 686      39584.5980          1.0                3
# 336      33406.5590          1.0                1
# 619      21560.4390          1.0                1
# 453      26259.1390          1.0                3
# 419      22946.6800          1.0                2
# 213       5345.0801          1.0                3
# 354      59211.5980          2.0                2
# 378      32816.4180          1.0                1
# 149      31666.5390          1.0                3
# 681      31775.6020          2.0                3
# 653      55814.3980          1.0                2
# 500      43183.2030          1.0                3
# 49       12949.2600          2.0                1
# 263      63631.0040          1.0                2
# 34       28670.6190          1.0                3
# 369      53044.1990          1.0                1
# 575      34137.2970          2.0                2
# 332      11220.6400          1.0                2
# 152      17100.0000          2.0                3
# 482      30289.4200          2.0                2
# 216      11060.2800          1.0                2
# 271      18365.0200          2.0                2
# 550      49479.8010          1.0                2
# 60       12097.6800          2.0                1
# 125      26557.4390          1.0                1
# 138      34456.8830          1.0                1
# 471      27143.0200          2.0                2
# 556      29457.2210          1.0                2
# 35       21044.4000          1.0                2
# 77       14881.1800          2.0                3
# 195      35091.8590          1.0                1
# 16       23265.1190          2.0                3
# 541      32294.6800          1.0                3
# 474      21630.3610          1.0                3
# 299      36307.0980          1.0                3
# 411      74335.6020          1.0                1
# 240      51459.5980          1.0                2
# 344      11521.9790          1.0                2
# 675      15476.2600          1.0                1

# %% [markdown]
# # Tabla de frecuencias variables

# %%
def tabla_serie(serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    x = PrettyTable()
    x = ColorTable(theme=Themes.OCEAN)
    x.field_names = ['Intervalo '+serie.name,
                     'Frecuencia absoluta', 'Frecuencia porcentual(%)']
    Intervalo = ''
    Frecuencia = ''
    Frecuencia_por = ''
    for i in np.arange(minimo, maximo-amplitud, amplitud):
        Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+')'
        Frecuencia = serie[(serie >= i) & (serie < i+amplitud)].count()
        Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
        x.add_row([Intervalo, Frecuencia, Frecuencia_por])
    i = maximo-amplitud
    Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+']'
    Frecuencia = serie[(serie >= i) & (serie <= i+amplitud)].count()
    Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
    x.add_row([Intervalo, Frecuencia, Frecuencia_por])

    return x


def tabla_datos_agrupados_1(datos):
    'Dada algunos datos devuelve su información tabulada, cada columna corresponde a una variable'
    print('Tablas de frecuencia datos agrupados')
    print(' ')
    print('Nota: El número de datos por columna es:', len(datos))
    for i in datos:
        print(' ')
        print(100*'-')
        print(' ')
        print(tabla_serie(datos[i]))
    return ''


print(tabla_datos_agrupados_1(muestra.drop(
    ['Dpto_residencia', 'Tipo_empleo', 'd_hijo6', 'hijos', 'inlf'], axis=1)))
# Out:
# Tablas de frecuencia datos agrupados
#
# Nota: El número de datos por columna es: 50
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |      [0.0,707.14)      |          31         |           62.0           |
# |    [707.14,1414.29)    |          5          |           10.0           |
# |   [1414.29,2121.43)    |          8          |           16.0           |
# |   [2121.43,2828.57)    |          4          |           8.0            |
# |   [2828.57,3535.71)    |          0          |           0.0            |
# |   [3535.71,4242.86)    |          1          |           2.0            |
# |    [4242.86,4950.0)    |          0          |           0.0            |
# |    [4242.86,4950.0]    |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [30.0,34.14)     |          6          |           12.0           |
# |     [34.14,38.29)     |          10         |           20.0           |
# |     [38.29,42.43)     |          8          |           16.0           |
# |     [42.43,46.57)     |          8          |           16.0           |
# |     [46.57,50.71)     |          10         |           20.0           |
# |     [50.71,54.86)     |          5          |           10.0           |
# |      [54.86,59.0]     |          3          |           6.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [8.0,9.29)      |          3          |           6.0            |
# |      [9.29,10.57)     |          2          |           4.0            |
# |     [10.57,11.86)     |          4          |           8.0            |
# |     [11.86,13.14)     |          26         |           52.0           |
# |     [13.14,14.43)     |          3          |           6.0            |
# |     [14.43,15.71)     |          1          |           2.0            |
# |      [15.71,17.0]     |          11         |           22.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |     [288.0,962.57)     |          1          |           2.0            |
# |    [962.57,1637.14)    |          4          |           8.0            |
# |   [1637.14,2311.71)    |          31         |           62.0           |
# |   [2311.71,2986.29)    |          9          |           18.0           |
# |   [2986.29,3660.86)    |          3          |           6.0            |
# |   [3660.86,4335.43)    |          1          |           2.0            |
# |    [4335.43,5010.0]    |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [31.0,35.14)     |          5          |           10.0           |
# |     [35.14,39.29)     |          8          |           16.0           |
# |     [39.29,43.43)     |          6          |           12.0           |
# |     [43.43,47.57)     |          11         |           22.0           |
# |     [47.57,51.71)     |          7          |           14.0           |
# |     [51.71,55.86)     |          9          |           18.0           |
# |      [55.86,60.0]     |          4          |           8.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [7.0,8.43)      |          6          |           12.0           |
# |      [8.43,9.86)      |          1          |           2.0            |
# |      [9.86,11.29)     |          7          |           14.0           |
# |     [11.29,12.71)     |          11         |           22.0           |
# |     [12.71,14.14)     |          5          |           10.0           |
# |     [14.14,15.57)     |          1          |           2.0            |
# |      [15.57,17.0]     |          19         |           38.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-------------------------+---------------------+--------------------------+
# |    Intervalo ingreso    | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-------------------------+---------------------+--------------------------+
# |   [269000.0,594142.86)  |          8          |           16.0           |
# |  [594142.86,919285.71)  |          12         |           24.0           |
# |  [919285.71,1244428.57) |          15         |           30.0           |
# | [1244428.57,1569571.43) |          5          |           10.0           |
# | [1569571.43,1894714.29) |          4          |           8.0            |
# | [1894714.29,2219857.14) |          5          |           10.0           |
# |  [2219857.14,2545000.0] |          1          |           2.0            |
# +-------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo exper_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |       [0.0,3.86)       |          9          |           18.0           |
# |      [3.86,7.71)       |          13         |           26.0           |
# |      [7.71,11.57)      |          8          |           16.0           |
# |     [11.57,15.43)      |          7          |           14.0           |
# |     [15.43,19.29)      |          7          |           14.0           |
# |     [19.29,23.14)      |          3          |           6.0            |
# |      [23.14,27.0]      |          3          |           6.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |      [0.0,5563.74)       |          22         |           44.0           |
# |    [5563.74,11127.49)    |          11         |           22.0           |
# |   [11127.49,16691.23)    |          10         |           20.0           |
# |   [16691.23,22254.97)    |          2          |           4.0            |
# |   [22254.97,27818.71)    |          2          |           4.0            |
# |   [27818.71,33382.46)    |          1          |           2.0            |
# |    [33382.46,38946.2)    |          1          |           2.0            |
# |    [33382.46,38946.2]    |          2          |           4.0            |
# +--------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |    [5345.08,15200.87)    |          10         |           20.0           |
# |   [15200.87,25056.66)    |          10         |           20.0           |
# |   [25056.66,34912.45)    |          17         |           34.0           |
# |   [34912.45,44768.24)    |          5          |           10.0           |
# |   [44768.24,54624.02)    |          3          |           6.0            |
# |   [54624.02,64479.81)    |          4          |           8.0            |
# |    [64479.81,74335.6]    |          1          |           2.0            |
# +--------------------------+---------------------+--------------------------+

# %% [markdown]
# # Salario promedio

# %%
mujeres = round(muestra['salario_esposa'].mean())
hombres = round(muestra['salario_esposo'].mean())
print('El salario promedio para los esposos es:', hombres)
print('El salario promedio para las esposas es:', mujeres)
# Out:
# El salario promedio para los esposos es: 29915
# El salario promedio para las esposas es: 8479

# %% [markdown]
# # Histograma edad esposo

# %%
fig, ax = plt.subplots()
ax.hist(muestra['edad_esposo'])
ax.set_xlabel('Edad esposo')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma edad esposo')
# Out:
# Text(0.5, 1.0, 'Histograma edad esposo')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %%
edad_promedio = round(muestra['edad_esposa'].mean())
print('La edad promedio de la esposa es: '+str(edad_promedio)+' años')
# Out:
# La edad promedio de la esposa es: 43 años

# %% [markdown]
# La probabilidad de A bajo la condición que ya ocurrió B es:
#
# $$P(A|B)= \frac{P(A \cap B)}{P(B)}$$
#
# Por lo tanto tenemos que la probabilidad de que este en el mercado laboral, dado que tiene una edad promedio es:
# $$P=\frac{tenga \ edad \ promedio \ y \ este \ en \ el \ mercado  \ laboral}{probabilidad \ de \ que \ tenga \ edad \ promedio}$$

# %%
def buscar_intervalo(edad, serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    for i in np.arange(minimo, maximo, amplitud):
        if edad in range(round(i), round(i+amplitud)):
            return [i, i+amplitud]

# %%
rango = buscar_intervalo(edad_promedio, muestra['edad_esposa'])
print('El intervalo considerado para la edad promedio de',
      edad_promedio, ' años es: ', rango)
print(100*'-')
P1 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1])])/len(muestra)*100
P2 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1]) & muestra['inlf'] == 1])/len(muestra)*100
P = round(P2/P1, 2)
print('La probabilidad de que la esposa de edad promedio participe en el mercado laboral es ', P, '%')
# Out:
# El intervalo considerado para la edad promedio de 43  años es:  [42.42857142857144, 46.571428571428584]
# ----------------------------------------------------------------------------------------------------
# La probabilidad de que la esposa de edad promedio participe en el mercado laboral es  0.75 %

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %% [markdown]
# **Como este evento es el evento complemento del anterior**, entonces la probabilidad es igual a $100\%-probabilidad \ evento \ anterior$

# %%
print('La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es ', 100-P, '%')
# Out:
# La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es  99.25 %
