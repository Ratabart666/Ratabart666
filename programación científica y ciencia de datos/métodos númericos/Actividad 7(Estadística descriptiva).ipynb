# %% [markdown]
# # Aclaraciones porfavor leer
#
# - Si alguna libreria no aparece porfavor instalar, en este caso installar prettytable y  ipympl con pip install prettytable y pip install ipympl. Si esto aún no funciona puede correr en mi binder https://mybinder.org/v2/gh/Ratabart666/Ratabart666/HEAD

# %% [markdown]
# # Datos y librerias

# %%
import pandas as pd
import numpy as np
from prettytable import MSWORD_FRIENDLY
from prettytable.colortable import ColorTable, Themes
from prettytable import PrettyTable
import matplotlib.pyplot as plt
datos = pd.read_csv('trabajo.txt', delimiter='\t')
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Visualizando datos, obteniendo muestras y aclarando información cada columna

# %% [markdown]
# **inlf**: 1 si participa la esposa en el mercado laboral, 0 de lo contrario
#
# **horas_esposa**:horas laboradas esposa
#
# **hijos** :número hijos menores a 6 años
#
# **edad_esposa**:edad en años esposa
#
# **educ_esposa**:años educación esposa
#
# **horas_esposo**:horas laboradas por el esposo
#
# **edad_esposo**:años de edad del esposo
#
# **educ_esposo**:años educación esposo
#
# **ingreso**:ingreso del hogar mensual
#
# **exper_esposa**:experiencia laboral en años
#
# **d_hijo6**:1 si tiene al menos un hijo menor de 6 años, 0 de lo contrario
#
# **salario_esposa**:salario laboral por hora esposa
#
# **salario_esposo**:salario laboral por hora esposa
#
# **Tipo_empleo**
#
# **Dpto_residencia**

# %%
datos
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 0       1          1610      1           32           12          2708
# 1       1          1656      0           30           12          2310
# 2       1          1980      1           35           12          3072
# 3       1           456      0           34           12          1920
# 4       1          1568      1           31           14          2000
# ..    ...           ...    ...          ...          ...           ...
# 748     0             0      0           40           13          3020
# 749     0             0      2           31           12          2056
# 750     0             0      0           43           12          2383
# 751     0             0      0           60           12          1705
# 752     0             0      0           39            9          3120
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 0             34           12   815500            14        1      12745.2000
# 1             30            9  1090000             5        0       5277.8203
# 2             40           12  1052000            15        1      17272.8980
# 3             53           10   365000             6        0       4166.7002
# 4             32           12  1365000             7        1      17448.8400
# ..           ...          ...      ...           ...      ...             ...
# 748           43           16  1410000             5        0          0.0000
# 749           33           12   500000            14        1          0.0000
# 750           43           12   497600             4        0          0.0000
# 751           55            8  1249200            15        0          0.0000
# 752           48           12  1418150            12        0          0.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 0        15309.4400          1.0                3
# 1        32078.0800          1.0                1
# 2        13606.6600          1.0                2
# 3        13458.4600          1.0                2
# 4        38000.0000          1.0                2
# ..              ...          ...              ...
# 748      35231.6990          1.0                1
# 749      18482.4390          1.0                3
# 750       4141.2402          1.0                2
# 751      47272.0000          1.0                2
# 752      23140.8610          2.0                1
#
# [753 rows x 15 columns]

# %%
muestra=datos.sample(50)

# %%
muestra
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 338     1          1886      0           38           12          1748
# 186     1          2750      0           37           16          2400
# 517     0             0      0           51           12          1575
# 453     0             0      0           53           12          1950
# 592     0             0      0           52            8          2452
# 134     1           630      0           45           11          1955
# 446     0             0      2           44           14          1920
# 229     1           336      0           37           12          1896
# 751     0             0      0           60           12          1705
# 405     1          2058      0           38           12          2601
# 523     0             0      0           46           12          2178
# 139     1          2025      0           50           12          1763
# 144     1           784      0           53            9          1990
# 42      1           583      1           31           16          1530
# 514     0             0      0           48           12          2450
# 379     1          2045      0           43            7          1968
# 550     0             0      0           50           12          1920
# 162     1           160      0           34           14          1626
# 447     0             0      0           45           12          2400
# 519     0             0      0           52           12          3280
# 156     1           180      1           33           12          3640
# 483     0             0      3           31           13          3600
# 60      1          2500      0           40           14          5010
# 499     0             0      0           52           12          2218
# 515     0             0      1           36           12          2062
# 312     1          1960      0           39           12          1800
# 114     1          2064      0           46           12          2805
# 3       1           456      0           34           12          1920
# 78      1            90      2           32           15          2350
# 409     1           778      0           47            8          2058
# 55      1          1830      0           31           16          1960
# 122     1          1823      0           43           12          1890
# 454     0             0      0           36           12          2128
# 299     1          1688      0           32           17          1863
# 359     1           675      0           38           12          3120
# 195     1          1984      0           40           12          1960
# 253     1          1939      0           31           13          2570
# 167     1          1052      0           46           14          1920
# 591     0             0      1           39           12          2412
# 318     1          1800      0           47           12          2520
# 680     0             0      0           42            8          1840
# 426     1          1760      0           33           12          3380
# 224     1          1515      0           46           16          1918
# 184     1           200      0           40           12          1350
# 87      1          1000      0           46            9          1927
# 637     0             0      0           54           12          2450
# 69      1           240      0           51           12          2250
# 411     1           225      1           40           17          1278
# 482     0             0      2           33           13          2677
# 507     0             0      0           42           12          2990
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 338           42            8  1196000            20        0      16884.5390
# 186           43           17  1678500            15        0      22800.0000
# 517           49            7   700000            25        0          0.0000
# 453           54           16  1388000            10        0          0.0000
# 592           54           12  1150000             0        0          0.0000
# 134           51           10  1243000             2        0       7841.2998
# 446           45           10   943700            10        1          0.0000
# 229           52            9   500000             4        0      11309.5610
# 751           55            8  1249200            15        0          0.0000
# 405           38           14  1152850            20        0      15279.4190
# 523           47           10  1477650            10        0          0.0000
# 139           54           13  1300000            22        0      16888.7190
# 144           60           10  1408000            11        0       4653.0996
# 42            34           16  1200000             6        1       9777.0205
# 514           51           12  1225000             4        0          0.0000
# 379           43           12  1098600            15        0      15051.4200
# 550           50           12  1470000             3        0          0.0000
# 162           38           14  1070000            19        0       4750.0000
# 447           45           12  1240000             3        0          0.0000
# 519           49           11  1008850            20        0          0.0000
# 156           33           11   125000             4        1       6333.4600
# 483           36           17  3680000             3        1          0.0000
# 60            42           13  1975000            19        0      16720.0000
# 499           51           11   730000            13        0          0.0000
# 515           38           14   852250             2        1          0.0000
# 312           43           12  1522750            19        0      25204.2600
# 114           47           12  2750000            15        0      22093.2010
# 3             53           10   365000             6        0       4166.7002
# 78            31           14   687750             9        1       3800.0000
# 409           51            8  1590500            11        0      12210.9200
# 55            35           14   995000             9        0      15366.0610
# 122           33           14   945000             3        0      16675.9200
# 454           42           12   454500             1        0          0.0000
# 299           33           17  1755000            15        0      38946.1990
# 359           42            8   337000            14        0       7059.6401
# 195           39           14  1401500             7        0      13943.7200
# 253           31           12   810000             4        0      12150.5000
# 167           48           16  2440000            15        0      17338.2600
# 591           36           14  1238000            13        1          0.0000
# 318           47           16  2632250            12        0      12666.5400
# 680           44            6   375000             5        0          0.0000
# 426           34           12  1500000            14        0      12954.5800
# 224           49           14  1929500            17        0      30099.0410
# 184           42           12  1311000             2        0      95000.0000
# 87            47           10   662500            19        0      10260.0000
# 637           54           13  1130500            13        0          0.0000
# 69            54           10   945000            24        0      14250.0000
# 411           38           17  1274500             8        1       6755.6396
# 482           37           17  2012500             4        1          0.0000
# 507           46           12   805000             2        0          0.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 338      22826.2190          1.0                1
# 186      27708.4590          2.0                2
# 517      27987.3790          1.0                2
# 453      26259.1390          1.0                3
# 592      30995.0800          2.0                3
# 134      25268.4800          2.0                1
# 446      35625.0000          1.0                3
# 229      18037.8400          1.0                3
# 751      47272.0000          1.0                2
# 405      20690.2400          1.0                1
# 523      50323.3980          1.0                1
# 139      32331.1580          1.0                2
# 144      27497.5590          2.0                1
# 42       52155.0000          2.0                2
# 514      32571.3180          1.0                2
# 379      25680.7790          1.0                2
# 550      49479.8010          1.0                2
# 162      44403.0000          2.0                3
# 447      31666.5390          1.0                3
# 519      12744.0600          2.0                3
# 156       2087.7200          2.0                3
# 483      73887.2030          2.0                2
# 60       12097.6800          2.0                1
# 499      24670.7400          2.0                1
# 515      31273.6210          2.0                1
# 312      31666.5390          2.0                1
# 114      47416.3980          2.0                2
# 3        13458.4600          1.0                2
# 78       18539.0590          2.0                1
# 409      28158.3810          2.0                1
# 55       24234.8810          2.0                1
# 122      16084.6400          2.0                3
# 454      16071.3400          1.0                3
# 299      36307.0980          1.0                3
# 359       5240.9600          1.0                2
# 195      35091.8590          1.0                1
# 253      14786.1800          1.0                1
# 167      55415.4020          2.0                3
# 591      38912.0000          2.0                2
# 318      52846.5980          2.0                1
# 680      15489.1800          2.0                3
# 426      26982.2790          2.0                3
# 224      33680.9220          2.0                1
# 184      50665.4020          1.0                1
# 87       19719.7210          2.0                1
# 637      13532.5600          1.0                3
# 69       30400.0000          1.0                1
# 411      74335.6020          1.0                1
# 482      30289.4200          2.0                2
# 507       8890.0996          1.0                1

# %% [markdown]
# # Tabla de frecuencias variables

# %%
def tabla_serie(serie):
    maximo=serie.max()
    minimo=serie.min()
    clases=round(1+np.log2(len(serie)))
    amplitud=(maximo-minimo)/clases
    x = PrettyTable()
    x = ColorTable(theme=Themes.OCEAN)
    x.field_names = ['Intervalo '+serie.name,'Frecuencia absoluta','Frecuencia porcentual(%)']
    Intervalo=''
    Frecuencia=''
    Frecuencia_por=''
    for i in np.arange(minimo,maximo-amplitud,amplitud):
        Intervalo='['+str(round(i,2))+','+str(round(i+amplitud,2))+')'
        Frecuencia=serie[(serie>=i) & (serie<=i+amplitud)].count()
        Frecuencia_por=round(Frecuencia/len(serie)*100,2)
        x.add_row([Intervalo,Frecuencia,Frecuencia_por])
    i=maximo-amplitud
    Intervalo='['+str(round(i,2))+','+str(round(i+amplitud,2))+']'
    Frecuencia=serie[(serie>=i) & (serie<=i+amplitud)].count()
    Frecuencia_por=round(Frecuencia/len(serie)*100,2)
    x.add_row([Intervalo,Frecuencia,Frecuencia_por])
    
    return x




def tabla_datos_agrupados_1(datos):
    'Dada algunos datos devuelve su información tabulada, cada columna corresponde a una variable'
    print('Tablas de frecuencia datos agrupados')
    print(' ')
    print('Nota: El número de datos por columna es:',len(datos))
    for i in datos:
        print(' ')
        print(100*'-')
        print(' ')
        print(tabla_serie(datos[i]))
    return ''
        
    


print(tabla_datos_agrupados_1(muestra.drop(['Dpto_residencia','Tipo_empleo','d_hijo6','hijos','inlf'],axis=1)))
# Out:
# Tablas de frecuencia datos agrupados
#
# Nota: El número de datos por columna es: 50
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |      [0.0,392.86)      |          26         |           52.0           |
# |    [392.86,785.71)     |          6          |           12.0           |
# |    [785.71,1178.57)    |          2          |           4.0            |
# |   [1178.57,1571.43)    |          1          |           2.0            |
# |   [1571.43,1964.29)    |          8          |           16.0           |
# |   [1964.29,2357.14)    |          5          |           10.0           |
# |    [2357.14,2750.0)    |          1          |           2.0            |
# |    [2357.14,2750.0]    |          2          |           4.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [31.0,35.14)     |          11         |           22.0           |
# |     [35.14,39.29)     |          9          |           18.0           |
# |     [39.29,43.43)     |          8          |           16.0           |
# |     [43.43,47.57)     |          10         |           20.0           |
# |     [47.57,51.71)     |          5          |           10.0           |
# |     [51.71,55.86)     |          6          |           12.0           |
# |      [55.86,60.0]     |          1          |           2.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [7.0,8.43)      |          4          |           8.0            |
# |      [8.43,9.86)      |          2          |           4.0            |
# |      [9.86,11.29)     |          1          |           2.0            |
# |     [11.29,12.71)     |          29         |           58.0           |
# |     [12.71,14.14)     |          7          |           14.0           |
# |     [14.14,15.57)     |          1          |           2.0            |
# |      [15.57,17.0]     |          6          |           12.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |    [1278.0,1811.14)    |          9          |           18.0           |
# |   [1811.14,2344.29)    |          22         |           44.0           |
# |   [2344.29,2877.43)    |          12         |           24.0           |
# |   [2877.43,3410.57)    |          4          |           8.0            |
# |   [3410.57,3943.71)    |          2          |           4.0            |
# |   [3943.71,4476.86)    |          0          |           0.0            |
# |    [4476.86,5010.0)    |          1          |           2.0            |
# |    [4476.86,5010.0]    |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [31.0,35.14)     |          8          |           16.0           |
# |     [35.14,39.29)     |          8          |           16.0           |
# |     [39.29,43.43)     |          8          |           16.0           |
# |     [43.43,47.57)     |          8          |           16.0           |
# |     [47.57,51.71)     |          9          |           18.0           |
# |     [51.71,55.86)     |          8          |           16.0           |
# |      [55.86,60.0]     |          1          |           2.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [6.0,7.57)      |          2          |           4.0            |
# |      [7.57,9.14)      |          5          |           10.0           |
# |      [9.14,10.71)     |          7          |           14.0           |
# |     [10.71,12.29)     |          15         |           30.0           |
# |     [12.29,13.86)     |          3          |           6.0            |
# |     [13.86,15.43)     |          9          |           18.0           |
# |      [15.43,17.0]     |          9          |           18.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-------------------------+---------------------+--------------------------+
# |    Intervalo ingreso    | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-------------------------+---------------------+--------------------------+
# |   [125000.0,632857.14)  |          6          |           12.0           |
# |  [632857.14,1140714.29) |          15         |           30.0           |
# | [1140714.29,1648571.43) |          20         |           40.0           |
# | [1648571.43,2156428.57) |          5          |           10.0           |
# | [2156428.57,2664285.71) |          2          |           4.0            |
# | [2664285.71,3172142.86) |          1          |           2.0            |
# |  [3172142.86,3680000.0) |          1          |           2.0            |
# |  [3172142.86,3680000.0] |          1          |           2.0            |
# +-------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo exper_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |       [0.0,3.57)       |          10         |           20.0           |
# |      [3.57,7.14)       |          9          |           18.0           |
# |      [7.14,10.71)      |          6          |           12.0           |
# |     [10.71,14.29)      |          8          |           16.0           |
# |     [14.29,17.86)      |          7          |           14.0           |
# |     [17.86,21.43)      |          7          |           14.0           |
# |      [21.43,25.0]      |          3          |           6.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |      [0.0,13571.43)      |          34         |           68.0           |
# |   [13571.43,27142.86)    |          13         |           26.0           |
# |   [27142.86,40714.29)    |          2          |           4.0            |
# |   [40714.29,54285.71)    |          0          |           0.0            |
# |   [54285.71,67857.14)    |          0          |           0.0            |
# |   [67857.14,81428.57)    |          0          |           0.0            |
# |    [81428.57,95000.0)    |          0          |           0.0            |
# |    [81428.57,95000.0]    |          1          |           2.0            |
# +--------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |    [2087.72,12408.85)    |          4          |           8.0            |
# |   [12408.85,22729.97)    |          11         |           22.0           |
# |    [22729.97,33051.1)    |          19         |           38.0           |
# |    [33051.1,43372.22)    |          5          |           10.0           |
# |   [43372.22,53693.35)    |          8          |           16.0           |
# |   [53693.35,64014.48)    |          1          |           2.0            |
# |    [64014.48,74335.6]    |          2          |           4.0            |
# +--------------------------+---------------------+--------------------------+

# %% [markdown]
# # Salario promedio

# %%
mujeres=round(muestra['salario_esposa'].mean())
hombres=round(muestra['salario_esposo'].mean())
print('El salario promedio para los esposos es:',hombres)
print('El salario promedio para las esposas es:',mujeres)
# Out:
# El salario promedio para los esposos es: 30475
# El salario promedio para las esposas es: 10385

# %% [markdown]
# # Histograma edad esposo

# %%
fig,ax=plt.subplots()
ax.hist(muestra['edad_esposo'])
ax.set_xlabel('Edad esposo')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma edad esposo')
# Out:
# Text(0.5, 1.0, 'Histograma edad esposo')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %%
edad_promedio=round(muestra['edad_esposa'].mean())
print('La edad promedio de la esposa es: '+str(edad_promedio)+' años')
# Out:
# La edad promedio de la esposa es: 42 años

# %% [markdown]
# La probabilidad de A bajo la condición que ya ocurrió B es:
#
# $$P(A|B)= \frac{P(A \cap B)}{P(B)}$$
#
# Por lo tanto tenemos que la probabilidad de que este en el mercado laboral, dado que tiene una edad promedio es:
# $$P=\frac{tenga \ edad \ promedio \ y \ este \ en \ el \ mercado  \ laboral}{probabilidad \ de \ que \ tenga \ edad \ promedio}$$

# %%
def buscar_intervalo(edad,serie):
    maximo=serie.max()
    minimo=serie.min()
    clases=round(1+np.log2(len(serie)))
    amplitud=(maximo-minimo)/clases
    for i in np.arange(minimo,maximo,amplitud):
        if edad in range(round(i),round(i+amplitud)):
            return [i,i+amplitud]

# %%
rango=buscar_intervalo(edad_promedio,muestra['edad_esposa']) 
print('El intervalo considerado para la edad promedio de',edad_promedio,' años es: ',rango)
print(100*'-')
P1=len(muestra[(muestra['edad_esposa'] >=rango[0]) & (muestra['edad_esposa'] <rango[1])])/len(muestra)*100
P2=len(muestra[(muestra['edad_esposa'] >=rango[0]) & (muestra['edad_esposa'] <rango[1]) & muestra['inlf']==1])/len(muestra)*100
P=round(P2/P1,2)
print('La probabilidad de que la esposa de edad promedio participe en el mercado laboral es ',P,'%')
# Out:
# El intervalo considerado para la edad promedio de 42  años es:  [39.28571428571429, 43.42857142857144]
# ----------------------------------------------------------------------------------------------------
# La probabilidad de que la esposa de edad promedio participe en el mercado laboral es  0.75 %

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %% [markdown]
# **Como este evento es el evento complemento del anterior**, entonces la probabilidad es igual a $100\%-probabilidad \ evento \ anterior$

# %%
print('La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es ',100-P,'%')
# Out:
# La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es  99.25 %
