# %% [markdown]
# # Máquina de turing no determinista que reconoce el lenguaje:
# $\{w \in \mathbb\sum^{*}$:w=v#v\}

# %%
from automata.tm.dtm import DTM

dtm = DTM(
    states={'q1','q2','q3','q4','q5','q6','q7','q8','q9'},
    input_symbols={'0','1'},
    tape_symbols={'0','1','#','.','x'},
    transitions={
#####################################################
        'q1': {
            '1': ('q3', 'x', 'R'),
            '0': ('q2', 'x', 'R'),
            '#': ('q8', '#', 'R')
        },
#####################################################
        
        'q2': {
            '0': ('q2', '0', 'R'),
            '1': ('q2', '1', 'R'), 
            '#': ('q4', '#', 'R')     
        },
#####################################################
        'q3': {
            '0': ('q3', '0', 'R'),
            '1': ('q3', '1', 'R'),
            '#': ('q5', '#', 'R')
        },
#####################################################
        'q4': {
            'x': ('q4', 'x', 'R'),
            '0': ('q6', 'x', 'L')
        },
#####################################################
        'q5': {
            'x': ('q5', 'x', 'R'),
            '1': ('q6', 'x', 'L')
        },
#####################################################
        'q6': {
            '0': ('q6', '0', 'L'),
            '1': ('q6', '1', 'L'),
            'x': ('q6', 'x', 'L'),
            '#': ('q7', '#', 'L')
        },
#####################################################
        'q7': {
            'x': ('q1', 'x', 'R'),
            '0': ('q7', '0', 'L'),
            '1': ('q7', '1', 'L')
        },
#####################################################
        'q8': {
            'x': ('q8', 'x', 'R'),
            '.': ('q9', '.', 'R')
        }, 
#####################################################          
    },
    initial_state='q1',
    blank_symbol='.',
    final_states={'q9'}#,'q10'}
)

    
result=list(dtm.read_input_stepwise('111111#111111'))
for i in result:
    print(i)
# Out:
# TMConfiguration('q1', TMTape('111111#111111', 0))
# TMConfiguration('q3', TMTape('x11111#111111', 1))
# TMConfiguration('q3', TMTape('x11111#111111', 2))
# TMConfiguration('q3', TMTape('x11111#111111', 3))
# TMConfiguration('q3', TMTape('x11111#111111', 4))
# TMConfiguration('q3', TMTape('x11111#111111', 5))
# TMConfiguration('q3', TMTape('x11111#111111', 6))
# TMConfiguration('q5', TMTape('x11111#111111', 7))
# TMConfiguration('q6', TMTape('x11111#x11111', 6))
# TMConfiguration('q7', TMTape('x11111#x11111', 5))
# TMConfiguration('q7', TMTape('x11111#x11111', 4))
# TMConfiguration('q7', TMTape('x11111#x11111', 3))
# TMConfiguration('q7', TMTape('x11111#x11111', 2))
# TMConfiguration('q7', TMTape('x11111#x11111', 1))
# TMConfiguration('q7', TMTape('x11111#x11111', 0))
# TMConfiguration('q1', TMTape('x11111#x11111', 1))
# TMConfiguration('q3', TMTape('xx1111#x11111', 2))
# TMConfiguration('q3', TMTape('xx1111#x11111', 3))
# TMConfiguration('q3', TMTape('xx1111#x11111', 4))
# TMConfiguration('q3', TMTape('xx1111#x11111', 5))
# TMConfiguration('q3', TMTape('xx1111#x11111', 6))
# TMConfiguration('q5', TMTape('xx1111#x11111', 7))
# TMConfiguration('q5', TMTape('xx1111#x11111', 8))
# TMConfiguration('q6', TMTape('xx1111#xx1111', 7))
# TMConfiguration('q6', TMTape('xx1111#xx1111', 6))
# TMConfiguration('q7', TMTape('xx1111#xx1111', 5))
# TMConfiguration('q7', TMTape('xx1111#xx1111', 4))
# TMConfiguration('q7', TMTape('xx1111#xx1111', 3))
# TMConfiguration('q7', TMTape('xx1111#xx1111', 2))
# TMConfiguration('q7', TMTape('xx1111#xx1111', 1))
# TMConfiguration('q1', TMTape('xx1111#xx1111', 2))
# TMConfiguration('q3', TMTape('xxx111#xx1111', 3))
# TMConfiguration('q3', TMTape('xxx111#xx1111', 4))
# TMConfiguration('q3', TMTape('xxx111#xx1111', 5))
# TMConfiguration('q3', TMTape('xxx111#xx1111', 6))
# TMConfiguration('q5', TMTape('xxx111#xx1111', 7))
# TMConfiguration('q5', TMTape('xxx111#xx1111', 8))
# TMConfiguration('q5', TMTape('xxx111#xx1111', 9))
# TMConfiguration('q6', TMTape('xxx111#xxx111', 8))
# TMConfiguration('q6', TMTape('xxx111#xxx111', 7))
# TMConfiguration('q6', TMTape('xxx111#xxx111', 6))
# TMConfiguration('q7', TMTape('xxx111#xxx111', 5))
# TMConfiguration('q7', TMTape('xxx111#xxx111', 4))
# TMConfiguration('q7', TMTape('xxx111#xxx111', 3))
# TMConfiguration('q7', TMTape('xxx111#xxx111', 2))
# TMConfiguration('q1', TMTape('xxx111#xxx111', 3))
# TMConfiguration('q3', TMTape('xxxx11#xxx111', 4))
# TMConfiguration('q3', TMTape('xxxx11#xxx111', 5))
# TMConfiguration('q3', TMTape('xxxx11#xxx111', 6))
# TMConfiguration('q5', TMTape('xxxx11#xxx111', 7))
# TMConfiguration('q5', TMTape('xxxx11#xxx111', 8))
# TMConfiguration('q5', TMTape('xxxx11#xxx111', 9))
# TMConfiguration('q5', TMTape('xxxx11#xxx111', 10))
# TMConfiguration('q6', TMTape('xxxx11#xxxx11', 9))
# TMConfiguration('q6', TMTape('xxxx11#xxxx11', 8))
# TMConfiguration('q6', TMTape('xxxx11#xxxx11', 7))
# TMConfiguration('q6', TMTape('xxxx11#xxxx11', 6))
# TMConfiguration('q7', TMTape('xxxx11#xxxx11', 5))
# TMConfiguration('q7', TMTape('xxxx11#xxxx11', 4))
# TMConfiguration('q7', TMTape('xxxx11#xxxx11', 3))
# TMConfiguration('q1', TMTape('xxxx11#xxxx11', 4))
# TMConfiguration('q3', TMTape('xxxxx1#xxxx11', 5))
# TMConfiguration('q3', TMTape('xxxxx1#xxxx11', 6))
# TMConfiguration('q5', TMTape('xxxxx1#xxxx11', 7))
# TMConfiguration('q5', TMTape('xxxxx1#xxxx11', 8))
# TMConfiguration('q5', TMTape('xxxxx1#xxxx11', 9))
# TMConfiguration('q5', TMTape('xxxxx1#xxxx11', 10))
# TMConfiguration('q5', TMTape('xxxxx1#xxxx11', 11))
# TMConfiguration('q6', TMTape('xxxxx1#xxxxx1', 10))
# TMConfiguration('q6', TMTape('xxxxx1#xxxxx1', 9))
# TMConfiguration('q6', TMTape('xxxxx1#xxxxx1', 8))
# TMConfiguration('q6', TMTape('xxxxx1#xxxxx1', 7))
# TMConfiguration('q6', TMTape('xxxxx1#xxxxx1', 6))
# TMConfiguration('q7', TMTape('xxxxx1#xxxxx1', 5))
# TMConfiguration('q7', TMTape('xxxxx1#xxxxx1', 4))
# TMConfiguration('q1', TMTape('xxxxx1#xxxxx1', 5))
# TMConfiguration('q3', TMTape('xxxxxx#xxxxx1', 6))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 7))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 8))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 9))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 10))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 11))
# TMConfiguration('q5', TMTape('xxxxxx#xxxxx1', 12))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 11))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 10))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 9))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 8))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 7))
# TMConfiguration('q6', TMTape('xxxxxx#xxxxxx', 6))
# TMConfiguration('q7', TMTape('xxxxxx#xxxxxx', 5))
# TMConfiguration('q1', TMTape('xxxxxx#xxxxxx', 6))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 7))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 8))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 9))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 10))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 11))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx', 12))
# TMConfiguration('q8', TMTape('xxxxxx#xxxxxx.', 13))
# TMConfiguration('q9', TMTape('xxxxxx#xxxxxx..', 14))
