# %% [markdown]
# # Aclaraciones porfavor leer
#
# - Si alguna libreria no aparece porfavor instalar, en este caso installar prettytable y  ipympl con pip install prettytable y pip install ipympl. Si esto aún no funciona puede correr en mi binder https://mybinder.org/v2/gh/Ratabart666/Ratabart666/HEAD

# %% [markdown]
# # Datos y librerias

# %%
import pandas as pd
import numpy as np
from prettytable import MSWORD_FRIENDLY
from prettytable.colortable import ColorTable, Themes
from prettytable import PrettyTable
import matplotlib.pyplot as plt
datos = pd.read_csv('trabajo.txt', delimiter='\t')
plt.style.use('dark_background')
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Visualizando datos, obteniendo muestras y aclarando información cada columna

# %% [markdown]
# **inlf**: 1 si participa la esposa en el mercado laboral, 0 de lo contrario
#
# **horas_esposa**:horas laboradas esposa
#
# **hijos** :número hijos menores a 6 años
#
# **edad_esposa**:edad en años esposa
#
# **educ_esposa**:años educación esposa
#
# **horas_esposo**:horas laboradas por el esposo
#
# **edad_esposo**:años de edad del esposo
#
# **educ_esposo**:años educación esposo
#
# **ingreso**:ingreso del hogar mensual
#
# **exper_esposa**:experiencia laboral en años
#
# **d_hijo6**:1 si tiene al menos un hijo menor de 6 años, 0 de lo contrario
#
# **salario_esposa**:salario laboral por hora esposa
#
# **salario_esposo**:salario laboral por hora esposa
#
# **Tipo_empleo**
#
# **Dpto_residencia**

# %%
datos
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 0       1          1610      1           32           12          2708
# 1       1          1656      0           30           12          2310
# 2       1          1980      1           35           12          3072
# 3       1           456      0           34           12          1920
# 4       1          1568      1           31           14          2000
# ..    ...           ...    ...          ...          ...           ...
# 748     0             0      0           40           13          3020
# 749     0             0      2           31           12          2056
# 750     0             0      0           43           12          2383
# 751     0             0      0           60           12          1705
# 752     0             0      0           39            9          3120
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 0             34           12   815500            14        1      12745.2000
# 1             30            9  1090000             5        0       5277.8203
# 2             40           12  1052000            15        1      17272.8980
# 3             53           10   365000             6        0       4166.7002
# 4             32           12  1365000             7        1      17448.8400
# ..           ...          ...      ...           ...      ...             ...
# 748           43           16  1410000             5        0          0.0000
# 749           33           12   500000            14        1          0.0000
# 750           43           12   497600             4        0          0.0000
# 751           55            8  1249200            15        0          0.0000
# 752           48           12  1418150            12        0          0.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 0        15309.4400          1.0                3
# 1        32078.0800          1.0                1
# 2        13606.6600          1.0                2
# 3        13458.4600          1.0                2
# 4        38000.0000          1.0                2
# ..              ...          ...              ...
# 748      35231.6990          1.0                1
# 749      18482.4390          1.0                3
# 750       4141.2402          1.0                2
# 751      47272.0000          1.0                2
# 752      23140.8610          2.0                1
#
# [753 rows x 15 columns]

# %%
muestra=datos.sample(50)

# %%
muestra
# Out:
#      inlf  horas_esposa  hijos  edad_esposa  educ_esposa  horas_esposo  \
# 399     1          3533      2           38           15          2000
# 578     0             0      0           45           10          2295
# 353     1           690      0           34           12          1824
# 43      1           480      0           48           12          3149
# 491     0             0      0           37           16          2916
# 710     0             0      1           30           12          2450
# 221     1           532      0           47           12          1968
# 621     0             0      0           52           11          2000
# 433     0             0      0           43           12          2012
# 164     1          1200      0           46           12          2140
# 155     1          1550      0           54           17          2350
# 542     0             0      0           41           15          2520
# 117     1          2000      0           45           12          1720
# 200     1          1960      0           40           12          2423
# 217     1          1878      0           33           11          2499
# 335     1          2000      0           32           12          2895
# 447     0             0      0           45           12          2400
# 566     0             0      0           56           12          2142
# 580     0             0      1           34           12          3315
# 12      1           240      1           30           12          2830
# 695     0             0      1           33           12          3366
# 544     0             0      0           46           12          2119
# 481     0             0      0           34           12          3185
# 257     1           660      1           53           12          2090
# 449     0             0      2           30           17          3570
# 34      1          2081      0           45           16          2140
# 530     0             0      1           51            7          2000
# 305     1           600      0           34           13          3020
# 673     0             0      1           48           11          1955
# 708     0             0      0           32           12          2250
# 203     1          1530      0           54           12          2695
# 557     0             0      0           44           12          2553
# 522     0             0      1           36           14          1846
# 17      1           640      0           39           12          2250
# 192     1           288      0           43           12          1975
# 474     0             0      0           38           12          2196
# 79      1          1174      0           58           12          1948
# 705     0             0      1           31            8          2805
# 398     1          1720      0           49           14          2600
# 450     0             0      0           39            8          2805
# 699     0             0      0           54           12          1350
# 665     0             0      0           55           12          1944
# 128     1          1516      0           54           16          2550
# 133     1          1875      0           38           13          2136
# 711     0             0      0           51           10          3432
# 703     0             0      0           53           12          1624
# 232     1          1410      1           30           12          2106
# 488     0             0      0           44            9          1900
# 35      1           690      0           42           11          1896
# 364     1          1200      0           46           12          2597
#
#      edad_esposo  educ_esposo  ingreso  exper_esposa  d_hijo6  salario_esposa  \
# 399           38            9  1821500            17        1      19360.2400
# 578           48           12  1500000             1        0          0.0000
# 353           36           13   740000            16        0       4405.7197
# 43            48            8  1108600            10        0      17242.5000
# 491           38           17  1431500             6        0          0.0000
# 710           36           14  1217500             3        1          0.0000
# 221           47           11  1435000             9        0      21428.5800
# 621           52           12   620000            19        0          0.0000
# 433           44           13  1091150             4        0          0.0000
# 164           48           12  1275800            22        0      15643.4610
# 155           58           17  1940000             8        0      26967.8400
# 542           42           16   922500             8        0          0.0000
# 117           49            6  1488700             9        0      22800.0000
# 200           40            8  2090000             9        0      17255.0410
# 217           35            8   832000            15        0      11505.2600
# 335           30           12   860000            15        0       9880.0000
# 447           45           12  1240000             3        0          0.0000
# 566           60           12   803650             3        0          0.0000
# 580           39           17  1235050             3        1          0.0000
# 12            33           16   775000             0        1       7916.5405
# 695           37           13   750000             0        1          0.0000
# 544           51            8  1206750             3        0          0.0000
# 481           41           13   785000             0        0          0.0000
# 257           59           12  1033750            24        1      13818.3200
# 449           32           17   807500            12        1          0.0000
# 34            47           17  1232800            27        0      14465.8400
# 530           52            7  2249400             0        1          0.0000
# 305           35           12   685000             4        0       8866.5400
# 673           46            8  1048400            25        1          0.0000
# 708           35           16  1149750             4        0          0.0000
# 203           53           12  1110000            14        0       4222.1797
# 557           31           16   942500            15        0          0.0000
# 522           50           16  1088400            15        1          0.0000
# 17            40           12   957550             6        0      19665.0000
# 192           43           12   687000             8        0      15833.4600
# 474           42           11   834100            19        0          0.0000
# 79            59           16  1767500             6        0       9710.5195
# 705           31           10   386000            10        1          0.0000
# 398           45           16  2105000            14        0       6627.9600
# 450           44           12   759450            15        0          0.0000
# 699           60           12  1750000            10        0          0.0000
# 665           53            7   653600             9        0          0.0000
# 128           55           12   987100            11        0       9023.8604
# 133           41           12  1865000             8        0      32426.5410
# 711           50           11   380400            20        0          0.0000
# 703           59            8   478000            30        0          0.0000
# 232           30           14  1304000            11        1      18865.1000
# 488           48            8   945000             1        0          0.0000
# 35            44            8   794850             0        0       9362.4395
# 364           48            8   770000            22        0       9500.0000
#
#      salario_esposo  Tipo_empleo  Dpto_residencia
# 399      26600.0000          2.0                1
# 578      26818.5000          1.0                1
# 353      29166.5200          1.0                3
# 43       24127.3400          2.0                2
# 491      35184.1990          1.0                3
# 710      37224.4220          1.0                3
# 221      32825.1600          1.0                1
# 621      22800.0000          1.0                2
# 433      23123.0000          1.0                3
# 164      34864.2380          2.0                2
# 155      42852.6020          1.0                2
# 542      27293.5000          1.0                2
# 117      26953.4000          1.0                3
# 200      48617.1990          1.0                3
# 217      16656.9200          1.0                3
# 335      15751.3810          2.0                1
# 447      31666.5390          1.0                3
# 566      28384.8590          2.0                2
# 580      15255.1010          1.0                1
# 12       20141.5200          1.0                1
# 695       7544.5200          1.0                3
# 544      27064.3590          1.0                3
# 481      10848.6190          2.0                3
# 257      24181.6800          1.0                1
# 449      17030.8400          1.0                3
# 34       28670.6190          1.0                3
# 530      39900.0000          1.0                1
# 305      18874.2190          2.0                1
# 673      15682.2210          2.0                1
# 708      38000.0000          1.0                1
# 203      25380.1990          1.0                2
# 557      20540.5200          1.0                1
# 522      39113.4020          1.0                3
# 17       23369.2400          2.0                1
# 192      22126.6410          1.0                3
# 474      21630.3610          1.0                3
# 79       35112.7620          2.0                3
# 705       9482.9004          1.0                2
# 398      27477.0410          2.0                2
# 450      20320.8810          1.0                1
# 699      45527.8010          1.0                3
# 665      15637.7600          2.0                3
# 128      11280.6800          2.0                2
# 133      37359.6990          2.0                3
# 711       5221.5801          1.0                3
# 703      11259.7800          2.0                1
# 232      32478.6000          1.0                3
# 488      37800.1210          2.0                2
# 35       21044.4000          1.0                2
# 364      17558.6600          1.0                3

# %% [markdown]
# # Tabla de frecuencias variables

# %%
def tabla_serie(serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    x = PrettyTable()
    x = ColorTable(theme=Themes.OCEAN)
    x.field_names = ['Intervalo '+serie.name,
                     'Frecuencia absoluta', 'Frecuencia porcentual(%)']
    Intervalo = ''
    Frecuencia = ''
    Frecuencia_por = ''
    for i in np.arange(minimo, maximo-amplitud, amplitud):
        Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+')'
        Frecuencia = serie[(serie >= i) & (serie < i+amplitud)].count()
        Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
        x.add_row([Intervalo, Frecuencia, Frecuencia_por])
    i = maximo-amplitud
    Intervalo = '['+str(round(i, 2))+','+str(round(i+amplitud, 2))+']'
    Frecuencia = serie[(serie >= i) & (serie <= i+amplitud)].count()
    Frecuencia_por = round(Frecuencia/len(serie)*100, 2)
    x.add_row([Intervalo, Frecuencia, Frecuencia_por])

    return x


def tabla_datos_agrupados_1(datos):
    'Dada algunos datos devuelve su información tabulada, cada columna corresponde a una variable'
    print('Tablas de frecuencia datos agrupados')
    print(' ')
    print('Nota: El número de datos por columna es:', len(datos))
    for i in datos:
        print(' ')
        print(100*'-')
        print(' ')
        print(tabla_serie(datos[i]))
    return ''


print(tabla_datos_agrupados_1(muestra.drop(
    ['Dpto_residencia', 'Tipo_empleo', 'd_hijo6', 'hijos', 'inlf'], axis=1)))
# Out:
# Tablas de frecuencia datos agrupados
#
# Nota: El número de datos por columna es: 50
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |      [0.0,504.71)      |          29         |           58.0           |
# |    [504.71,1009.43)    |          6          |           12.0           |
# |   [1009.43,1514.14)    |          4          |           8.0            |
# |   [1514.14,2018.86)    |          9          |           18.0           |
# |   [2018.86,2523.57)    |          1          |           2.0            |
# |   [2523.57,3028.29)    |          0          |           0.0            |
# |    [3028.29,3533.0]    |          1          |           2.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [30.0,34.0)      |          9          |           18.0           |
# |      [34.0,38.0)      |          6          |           12.0           |
# |      [38.0,42.0)      |          7          |           14.0           |
# |      [42.0,46.0)      |          9          |           18.0           |
# |      [46.0,50.0)      |          7          |           14.0           |
# |      [50.0,54.0)      |          5          |           10.0           |
# |      [54.0,58.0]      |          7          |           14.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [7.0,8.43)      |          3          |           6.0            |
# |      [8.43,9.86)      |          1          |           2.0            |
# |      [9.86,11.29)     |          6          |           12.0           |
# |     [11.29,12.71)     |          29         |           58.0           |
# |     [12.71,14.14)     |          4          |           8.0            |
# |     [14.14,15.57)     |          2          |           4.0            |
# |      [15.57,17.0]     |          5          |           10.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo horas_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |    [1350.0,1667.14)    |          2          |           4.0            |
# |   [1667.14,1984.29)    |          10         |           20.0           |
# |   [1984.29,2301.43)    |          15         |           30.0           |
# |   [2301.43,2618.57)    |          10         |           20.0           |
# |   [2618.57,2935.71)    |          6          |           12.0           |
# |   [2935.71,3252.86)    |          3          |           6.0            |
# |    [3252.86,3570.0]    |          4          |           8.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo edad_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |      [30.0,34.29)     |          6          |           12.0           |
# |     [34.29,38.57)     |          8          |           16.0           |
# |     [38.57,42.86)     |          7          |           14.0           |
# |     [42.86,47.14)     |          9          |           18.0           |
# |     [47.14,51.43)     |          9          |           18.0           |
# |     [51.43,55.71)     |          5          |           10.0           |
# |      [55.71,60.0]     |          6          |           12.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# | Intervalo educ_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |       [6.0,7.57)      |          3          |           6.0            |
# |      [7.57,9.14)      |          10         |           20.0           |
# |      [9.14,10.71)     |          1          |           2.0            |
# |     [10.71,12.29)     |          18         |           36.0           |
# |     [12.29,13.86)     |          4          |           8.0            |
# |     [13.86,15.43)     |          2          |           4.0            |
# |      [15.43,17.0]     |          12         |           24.0           |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +-----------------------+---------------------+--------------------------+
# |   Intervalo ingreso   | Frecuencia absoluta | Frecuencia porcentual(%) |
# +-----------------------+---------------------+--------------------------+
# |  [380400.0,647400.0)  |          4          |           8.0            |
# |  [647400.0,914400.0)  |          15         |           30.0           |
# |  [914400.0,1181400.0) |          12         |           24.0           |
# | [1181400.0,1448400.0) |          9          |           18.0           |
# | [1448400.0,1715400.0) |          2          |           4.0            |
# | [1715400.0,1982400.0) |          5          |           10.0           |
# | [1982400.0,2249400.0] |          3          |           6.0            |
# +-----------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +------------------------+---------------------+--------------------------+
# | Intervalo exper_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +------------------------+---------------------+--------------------------+
# |       [0.0,4.29)       |          15         |           30.0           |
# |      [4.29,8.57)       |          7          |           14.0           |
# |      [8.57,12.86)      |          10         |           20.0           |
# |     [12.86,17.14)      |          9          |           18.0           |
# |     [17.14,21.43)      |          3          |           6.0            |
# |     [21.43,25.71)      |          4          |           8.0            |
# |      [25.71,30.0]      |          2          |           4.0            |
# +------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposa | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |      [0.0,4632.36)       |          28         |           56.0           |
# |    [4632.36,9264.73)     |          4          |           8.0            |
# |    [9264.73,13897.09)    |          6          |           12.0           |
# |   [13897.09,18529.45)    |          5          |           10.0           |
# |   [18529.45,23161.82)    |          5          |           10.0           |
# |   [23161.82,27794.18)    |          1          |           2.0            |
# |   [27794.18,32426.54]    |          1          |           2.0            |
# +--------------------------+---------------------+--------------------------+
#
# ----------------------------------------------------------------------------------------------------
#
# +--------------------------+---------------------+--------------------------+
# | Intervalo salario_esposo | Frecuencia absoluta | Frecuencia porcentual(%) |
# +--------------------------+---------------------+--------------------------+
# |    [5221.58,11420.95)    |          6          |           12.0           |
# |   [11420.95,17620.33)    |          7          |           14.0           |
# |    [17620.33,23819.7)    |          10         |           20.0           |
# |    [23819.7,30019.08)    |          12         |           24.0           |
# |   [30019.08,36218.45)    |          6          |           12.0           |
# |   [36218.45,42417.82)    |          6          |           12.0           |
# |    [42417.82,48617.2]    |          3          |           6.0            |
# +--------------------------+---------------------+--------------------------+

# %% [markdown]
# # Salario promedio

# %%
mujeres = round(muestra['salario_esposa'].mean())
hombres = round(muestra['salario_esposo'].mean())
print('El salario promedio para los esposos es:', hombres)
print('El salario promedio para las esposas es:', mujeres)
# Out:
# El salario promedio para los esposos es: 25477
# El salario promedio para las esposas es: 6936

# %% [markdown]
# # Histograma edad esposo

# %%
fig, ax = plt.subplots()
ax.hist(muestra['edad_esposo'])
ax.set_xlabel('Edad esposo')
ax.set_ylabel('Frecuencia')
ax.set_title('Histograma edad esposo')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %%
edad_promedio = round(muestra['edad_esposa'].mean())
print('La edad promedio de la esposa es: '+str(edad_promedio)+' años')
# Out:
# La edad promedio de la esposa es: 43 años

# %% [markdown]
# La probabilidad de A bajo la condición que ya ocurrió B es:
#
# $$P(A|B)= \frac{P(A \cap B)}{P(B)}$$
#
# Por lo tanto tenemos que la probabilidad de que este en el mercado laboral, dado que tiene una edad promedio es:
# $$P=\frac{tenga \ edad \ promedio \ y \ este \ en \ el \ mercado  \ laboral}{probabilidad \ de \ que \ tenga \ edad \ promedio}$$

# %%
def buscar_intervalo(edad, serie):
    maximo = serie.max()
    minimo = serie.min()
    clases = round(1+np.log2(len(serie)))
    amplitud = (maximo-minimo)/clases
    for i in np.arange(minimo, maximo, amplitud):
        if edad in range(round(i), round(i+amplitud)):
            return [i, i+amplitud]

# %%
rango = buscar_intervalo(edad_promedio, muestra['edad_esposa'])
print('El intervalo considerado para la edad promedio de',
      edad_promedio, ' años es: ', rango)
print(100*'-')
P1 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1])])/len(muestra)*100
P2 = len(muestra[(muestra['edad_esposa'] >= rango[0]) & (
    muestra['edad_esposa'] < rango[1]) & muestra['inlf'] == 1])/len(muestra)*100
P = round(P2/P1, 2)
print('La probabilidad de que la esposa de edad promedio participe en el mercado laboral es ', P, '%')
# Out:
# El intervalo considerado para la edad promedio de 43  años es:  [42.0, 46.0]
# ----------------------------------------------------------------------------------------------------
# La probabilidad de que la esposa de edad promedio participe en el mercado laboral es  0.44 %

# %% [markdown]
# # Probabilidad de que la esposa de edad promedio participe en el mercado laboral

# %% [markdown]
# **Como este evento es el evento complemento del anterior**, entonces la probabilidad es igual a $100\%-probabilidad \ evento \ anterior$

# %%
print('La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es ', 100-P, '%')
# Out:
# La probabilidad de que la esposa de edad promedio no participe en el mercado laboral es  99.56 %
